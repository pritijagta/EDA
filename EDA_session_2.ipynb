# %% [markdown]
# ### How to read DataFrame

# %%
import pandas as pd
Names=['priti','raj','om','sita','manasi']
Age=[23,33,44,55,66]
df=pd.DataFrame(zip(Names,Age),columns=['Names','Age'])

# %%
pd.read_csv('data.csv')
# Out:
#   Names  Age    City
# 0     A   12    pune
# 1     B   23     mum
# 2     C   34  nashik
# 3     D   56       T

# %%
pd.read_excel('data2.xslx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 pd.read_excel('data2.xslx')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
#     482         "an ExcelFile - ExcelFile already has the engine set"
#     483     )
#
# ...

# %%
visa_df=pd.read_csv('Visadataset.csv')

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.shape
print(f'No of rows are {visa_df.shape[0]}')
# Out:
# No of rows are 25480

# %%
pd.read_csv('bank.csv',sep=';')
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# ### Dictionary as Dataframe

# %%
dict1={'Names':['priti','snehal','shubham'],'Age':[23,44,55],'City':['Nashik','Pune','Mumbai']}

# %%
dict1
# Out:
# {'Names': ['priti', 'snehal', 'shubham'],
#  'Age': [23, 44, 55],
#  'City': ['Nashik', 'Pune', 'Mumbai']}

# %%
pd.DataFrame(dict1)
# Out:
#      Names  Age    City
# 0    priti   23  Nashik
# 1   snehal   44    Pune
# 2  shubham   55  Mumbai

# %%
dict2={'Name':'priti','Age':34,'City':'Nashik'}
pd.DataFrame(dict2,index=[1,2,3])
# Out:
#     Name  Age    City
# 1  priti   34  Nashik
# 2  priti   34  Nashik
# 3  priti   34  Nashik
